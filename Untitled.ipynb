# %%
from bs4 import BeautifulSoup as bs
import requests

# url = 'http://localhost/HTML/Structure-HTML.html'
# req = requests.get(url)

# %%
req.text
# Out:
# '<html lang="en">\r\n    <head>\r\n        <meta charset="UTF-8">\r\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n        <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n        <title>HTML Class</title>\r\n    </head>\r\n    <body>\r\n        <p>Lorem, ipsum dolor sit amet consectetur adipisicing elit. Voluptatibus quia deserunt aperiam culpa.\r\n            Porro magni ipsam nulla, voluptates dolor distinctio vel, explicabo inventore nisi nemo temporibus \r\n            praesentium, veritatis eos molestias. \r\n        </p>\r\n        <p>\r\n            Lorem ipsum dolor sit amet consectetur, adipisicing elit. Deleniti, at laboriosam. Illum, ipsa \r\n            voluptatem laborum beatae cumque tenetur rerum ea! Molestias omnis ab perspiciatis similique neque \r\n            error, autem veniam ipsum.\r\n        </p>\r\n        <a href="C:\\Users\\emeto\\Downloads\\Projects\\Teaching\\Scripts\\HTML\\test-link.html">Click to go test-link
# ...

# %%
soup = bs(req.text,"html5lib")

# %%
soup.title
# Out:
# <title>HTML Class</title>

# %%
soup.p
# Out:
# <p>Lorem, ipsum dolor sit amet consectetur adipisicing elit. Voluptatibus quia deserunt aperiam culpa.
#             Porro magni ipsam nulla, voluptates dolor distinctio vel, explicabo inventore nisi nemo temporibus
#             praesentium, veritatis eos molestias.
#         </p>

# %%
soup.a
# Out:
# <a href="C:\Users\emeto\Downloads\Projects\Teaching\Scripts\HTML\test-link.html">Click to go test-link</a>

# %%
anchors = soup.find_all('p')
anchors
# Out:
# [<p>Lorem, ipsum dolor sit amet consectetur adipisicing elit. Voluptatibus quia deserunt aperiam culpa.
#              Porro magni ipsam nulla, voluptates dolor distinctio vel, explicabo inventore nisi nemo temporibus
#              praesentium, veritatis eos molestias.
#          </p>,
#  <p>
#              Lorem ipsum dolor sit amet consectetur, adipisicing elit. Deleniti, at laboriosam. Illum, ipsa
#              voluptatem laborum beatae cumque tenetur rerum ea! Molestias omnis ab perspiciatis similique neque
#              error, autem veniam ipsum.
#          </p>]

# %%
https://web.facebook.com/explore.datascience/

# %%
url = 'https://web.facebook.com/explore.datascience/'
req = requests.get(url)

# %%
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script nonce="7BUeoPwX">window._cstart=+new Date();</script><script nonce="7BUeoPwX">function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"hostnameRewriterConfig":{"site":"internet.org","inboundName":"web.facebook.com","cdnDomainName":null},"ajaxpipe_token":"AXgHnylSoofCiRhGdnc","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"isHeartbeatEnabled":true,"isArtilleryOn":false},"shouldLogCounters":true,"timeslice_categories":{"react_render":true,"reflow":true},"sample_continuation_stacktraces":true,"dom_muta
# ...

# %%
soup = bs(req.text,"html5lib")

# %%
for text in soup.find_all('p'):
    print(text.text)
# Out:
# 5 out of 5 stars.
# Explore Data Science Academy will be launching a 12-month part-time Data Engineering course on the 12th of July.
#  This article outlines what Data Engineering is. - https://realpython.com/python-data-engineer/
#  Pop over to our website for a detailed breakdown of what the course entails. - https://explore-datascience.net/course/info/3/3/online
# There are numerous data science resources available, but sometimes it takes a bit of time to find the best ones.
#  Dataquest.io has compiled a list of resources recommended by the community. The resources include courses, competitions, blogs and career guidance.
#  https://www.dataquest.io/data-science-resources/#tab-con-2
#  #datascience #education #resourcesharing
